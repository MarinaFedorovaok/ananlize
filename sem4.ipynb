# %%
import pandas as pd

# %%
df = pd.read_csv("laptops_10.csv")

# %%
df.head(5)
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %% [markdown]
# 1.1 Изучите количество памяти с помощью matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 4))

plt.hist(df['Ram'], bins=25)

plt.title('Ram')
plt.xlabel('Volume')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %% [markdown]
# 1.2 Изучите стоимость ноутбуков с помощью matplotlib

# %%
plt.figure(figsize=(6, 4))

plt.hist(df['Price_euros'], bins=25)

plt.title('Price')
plt.xlabel('euro')
# Out:
# Text(0.5, 0, 'euro')

# %% [markdown]
# 1.3 Изучите вес ноутбуков с помощью matplotlib
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы

# %%
plt.figure(figsize=(6, 4))

plt.hist(df['Weight'], bins=25)

plt.title('Weight')
# Out:
# Text(0.5, 1.0, 'Weight')

# %% [markdown]
# 2.1 Изучите распределение типов носителя
# 2.2 Изучите распределение компаний производителей
# 2.3 Изучите распределение операционной системы
# 2.4 Изучите распределение компаний производителей CPU

# %%
data = df['Memory_Type'].value_counts().reset_index()
data.head()
# Out:
#           index  Memory_Type
# 0           SSD          641
# 1           HDD          576
# 2  FlashStorage           74
# 3        Hybrid           12

# %%
plt.figure(figsize=(10, 10))

plt.pie(data['Memory_Type'], autopct='%1.1f%%')

plt.legend(data['index']);

# %%
data1 = df['Company'].value_counts().reset_index()
data1.head()
# Out:
#     index  Company
# 0    Dell      297
# 1  Lenovo      297
# 2      HP      274
# 3    Asus      158
# 4    Acer      103

# %%
plt.figure(figsize=(6, 4))

plt.bar(data1['index'], data1['Company'])

plt.title('Производители')
plt.xticks(rotation=90);

# %%
data = df['OpSys'].value_counts().reset_index()
data.head()
# Out:
#         index  OpSys
# 0  Windows 10   1072
# 1       No OS     66
# 2       Linux     62
# 3   Windows 7     45
# 4   Chrome OS     27

# %%
plt.figure(figsize=(6, 4))
plt.minorticks_on()
plt.grid()

plt.bar(data['index'], data['OpSys'])

plt.title('OC')
plt.xticks(rotation=90);

# %%
data2 = df[df['Cpu_Company'] != 'Samsung']
data2.head(10)
# Out:
#   Company          Product   TypeName  Inches                         Cpu  \
# 0   Apple      MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz
# 1   Apple      Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 2      HP           250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz
# 3   Apple      MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz
# 4   Apple      MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz
# 5    Acer         Aspire 3   Notebook    15.6     AMD A9-Series 9420 3GHz
# 6   Apple      MacBook Pro  Ultrabook    15.4        Intel Core i7 2.2GHz
# 7   Apple      Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 8    Asus  ZenBook UX430UN  Ultrabook    14.0  Intel Core i7 8550U 1.8GHz
# 9    Acer          Swift 3  Ultrabook    14.0  Intel Core i5 8250U 1.6GHz
#
#     Ram                           Gpu       OpSys  Weight  Price_euros  \
# 0   8GB  Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# ...

# %%
data3 = data2['Cpu_Company'].value_counts().reset_index()
data3.head(4)
# Out:
#    index  Cpu_Company
# 0  Intel         1240
# 1    AMD           62

# %%
data2
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
plt.figure(figsize=(10, 10))

plt.pie(data3['Cpu_Company'], autopct='%1.1f%%')

plt.legend(data3['index']);

# %% [markdown]
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму
# Процессоры от Samsung не изучайте
#
# 3.1 Постройте график в абсолютных величинах
# 3.2 Постройте график в относительных величинах

# %%
import numpy as np

# %%
plt.figure(figsize=(8, 6))

# определяем кол-во делений
n_ticks = np.arange(len(data['Cpu_Company']))

# %%
data4 = pd.crosstab(data2["Company"], data2['Cpu_Company'])
data4
# Out:
# Cpu_Company  AMD  Intel
# Company
# Acer          10     93
# Apple          0     21
# Asus          11    147
# Chuwi          0      3
# Dell           0    297
# Fujitsu        0      3
# Google         0      3
# HP            25    249
# Huawei         0      2
# LG             0      3
# Lenovo        16    281
# MSI            0     54
# Mediacom       0      7
# Microsoft      0      6
# Razer          0      7
# Samsung        0      8
# Toshiba        0     48
# Vero           0      4
# Xiaomi         0      4

# %%
data5 = data4.reset_index()

# %%
plt.figure(figsize=(8, 6))

# определяем кол-во делений
n_ticks = np.arange(len(data5['Intel']))

# определяем сдвиг
offset = 0.2

# определяем ширину столбцов
w = 0.4

# добавляем сдвиг к кол-ву делений
plt.bar(n_ticks - offset, data5['Intel'], width=w)
plt.bar(n_ticks + offset, data5['AMD'], width=w)

plt.legend(['Intel', 'AMD'])
plt.xticks(n_ticks, data5['Company'], rotation = 90);  # добавляем метки делений

# %%
plt.figure(figsize=(8, 6))

# определяем кол-во делений
n_ticks = np.arange(len(data['Cpu_Company']))

# определяем сдвиг
offset = 0.2

# определяем ширину столбцов
w = 0.4

# %%
data5
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
data2
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
# Готовим данные для графика

data6 = pd.crosstab(data2['Company'], data2['Cpu_Company'], normalize='index').reset_index()
data6.rename(columns={0: 'AMD', 1: 'Intel'}, inplace=True)
data6.head(16)
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Samsung  0.000000  1.000000

# %%
plt.figure(figsize=(8, 6))

plt.bar(data6['Company'], data6['AMD'])
plt.bar(data6['Company'], data6['Intel'], bottom=data6['AMD'])

plt.legend(['AMD', 'Intel'])
plt.xticks(rotation = 90);
