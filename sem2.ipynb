# %%
pd.read_csv('./laptop.csn', header=1)

# %%
import pandas as pd

# %%
df = pd.read_csv('laptops.csv', header=1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df = pd.read_csv('laptops.csv', header=1)
#
# File /lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df= pd.read
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/4248710/attachment/5f6b595e63350aa5b55f0ea72561b871.csv')
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/4248710/attachment/5f6b595e63350aa5b55f0ea72561b871.csv')
#
# File /lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('./laptops.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df = pd.read_csv('./laptops.csv')
#
# File /lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/4248710/attachment/5f6b595e63350aa5b55f0ea72561b871.csv')
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/4248710/attachment/5f6b595e63350aa5b55f0ea72561b871.csv')
#
# File /lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('./laptops.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df = pd.read_csv('./laptops.csv')
#
# File /lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('./laptops.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df = pd.read_csv('./laptops.csv')
#
# File /lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('./laptops.csv', sep = ';')

# %%
df.top(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df.top(10)
#
# File /lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'top'

# %%
df.head(10)
# Out:
#   Company          Product   TypeName  Inches  \
# 0   Apple      MacBook Pro  Ultrabook    13.3
# 1   Apple      Macbook Air  Ultrabook    13.3
# 2      HP           250 G6   Notebook    15.6
# 3   Apple      MacBook Pro  Ultrabook    15.4
# 4   Apple      MacBook Pro  Ultrabook    13.3
# 5    Acer         Aspire 3   Notebook    15.6
# 6   Apple      MacBook Pro  Ultrabook    15.4
# 7   Apple      Macbook Air  Ultrabook    13.3
# 8    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
# ...

# %%
df.attrs
# Out:
# {}

# %%
df.info
# Out:
# <bound method DataFrame.info of      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 71.3+ KB

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
df.describe('Company')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df.describe('Company')
#
# File /lib/python3.10/site-packages/pandas/core/generic.py:10225, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9976 @final
#    9977 def describe(
#    9978     self: NDFrameT,
#    (...)
#    9982     datetime_is_numeric=False,
#    9983 ) -> NDFrameT:
#    9984     """
#    9985     Generate descriptive statistics.
#    9986
#    (...)
#   10223     max            NaN      3.0
#   10224     """
# > 10225     return describe_ndframe(
#   10226         obj=self,
#   10227         include=include,
#   10228         exclude=exclude,
#   10229         datetime_is_numeric=datetime_is_numeric,
#   10230         percentiles=percentiles,
#   10231     )
#
# ...

# %%
df.describe(include = ['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df.sort_values(['Company'])
# Out:
#      Company                                   Product   TypeName  Inches  \
# 651     Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce     Gaming    15.6
# 78      Acer                      Aspire A515-51G-32MX   Notebook    15.6
# 324     Acer                                  Aspire 5   Notebook    15.6
# 326     Acer                             Aspire E5-575   Notebook    15.6
# 371     Acer                                  Aspire 3   Notebook    15.6
# ...      ...                                       ...        ...     ...
# 1120    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)   Notebook    13.3
# 877   Xiaomi                               Mi Notebook  Ultrabook    13.3
# 184   Xiaomi                               Mi Notebook   Notebook    15.6
# 514   Xiaomi                               Mi Notebook   Notebook    15.6
# 192   Xiaomi                               Mi Notebook  Ultrabook    13.3
#
#                  ScreenResolution                          Cpu   Ram  \
# ...

# %%
df.sort_values(['Price_euros'])
# Out:
#      Company                               Product     TypeName  Inches  \
# 1215    Acer      C740-C9QX (3205U/2GB/32GB/Chrome      Netbook    11.6
# 20      Asus                       Vivobook E200HA      Netbook    11.6
# 1120    Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)     Notebook    13.3
# 31      Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)     Notebook    14.0
# 290     Acer                  Chromebook C910-C2ST     Notebook    15.6
# ...      ...                                   ...          ...     ...
# 1066    Asus                            ROG G701VO       Gaming    17.3
# 749       HP                              Zbook 17  Workstation    17.3
# 610   Lenovo                          Thinkpad P51     Notebook    15.6
# 830    Razer                             Blade Pro       Gaming    17.3
# 196    Razer                             Blade Pro       Gaming    17.3
#
#                          ScreenResolution  \
# 1215                             1366x768
# ...

# %%
df['Price_euros'].min()
# Out:
# 174.0

# %%
df['Price_euros'].max()
# Out:
# 6099.0

# %%
df.loc[196]
# Out:
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                32GB
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                           3.49kg
# Price_euros                                      6099.0
# Name: 196, dtype: object

# %%
df.iloc[0]
# Out:
# Company                                          Apple
# Product                                    MacBook Pro
# TypeName                                     Ultrabook
# Inches                                            13.3
# ScreenResolution    IPS Panel Retina Display 2560x1600
# Cpu                               Intel Core i5 2.3GHz
# Ram                                                8GB
# Memory                                       128GB SSD
# Gpu                       Intel Iris Plus Graphics 640
# OpSys                                            macOS
# Weight                                          1.37kg
# Price_euros                                    1339.69
# Name: 0, dtype: object

# %%
df.sort_values(['Inches'])
# Out:
#      Company          Product            TypeName  Inches  \
# 1114  Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 1126  Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 1082  Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 50    Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 944   Lenovo   Yoga 700-11ISK  2 in 1 Convertible    11.3
# ...      ...              ...                 ...     ...
# 1129      HP           Omen -              Gaming    17.3
# 578      MSI     GT73VR Titan              Gaming    17.3
# 257       HP   Envy 17-U275cl            Notebook    17.3
# 1136      HP         ZBook 17         Workstation    17.3
# 177      MSI  GT80S 6QF-074US              Gaming    18.4
#
#                                ScreenResolution                          Cpu  \
# 1114            IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# 1126            IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# ...

# %%
df.head(10)
# Out:
#   Company          Product   TypeName  Inches  \
# 0   Apple      MacBook Pro  Ultrabook    13.3
# 1   Apple      Macbook Air  Ultrabook    13.3
# 2      HP           250 G6   Notebook    15.6
# 3   Apple      MacBook Pro  Ultrabook    15.4
# 4   Apple      MacBook Pro  Ultrabook    13.3
# 5    Acer         Aspire 3   Notebook    15.6
# 6   Apple      MacBook Pro  Ultrabook    15.4
# 7   Apple      Macbook Air  Ultrabook    13.3
# 8    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
# ...

# %%
df_inches = df.sort_values(['Inches'])

# %%
df_inches.head(10)
# Out:
#      Company          Product            TypeName  Inches  \
# 1114  Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 1126  Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 1082  Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 50    Lenovo        Yoga Book  2 in 1 Convertible    10.1
# 944   Lenovo   Yoga 700-11ISK  2 in 1 Convertible    11.3
# 461     Acer     TravelMate B             Netbook    11.6
# 409   Lenovo   Lenovo IdeaPad            Notebook    11.6
# 455     Dell    Inspiron 3168  2 in 1 Convertible    11.6
# 677       HP  Chromebook X360  2 in 1 Convertible    11.6
# 515     Asus     VivoBook E12             Netbook    11.6
#
#                                ScreenResolution  \
# 1114            IPS Panel Touchscreen 1920x1200
# 1126            IPS Panel Touchscreen 1920x1200
# 1082            IPS Panel Touchscreen 1920x1200
# 50              IPS Panel Touchscreen 1920x1200
# 944   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df_inches[['Company', 'TypeName']]
# Out:
#      Company            TypeName
# 1114  Lenovo  2 in 1 Convertible
# 1126  Lenovo  2 in 1 Convertible
# 1082  Lenovo  2 in 1 Convertible
# 50    Lenovo  2 in 1 Convertible
# 944   Lenovo  2 in 1 Convertible
# ...      ...                 ...
# 1129      HP              Gaming
# 578      MSI              Gaming
# 257       HP            Notebook
# 1136      HP         Workstation
# 177      MSI              Gaming
#
# [1303 rows x 2 columns]

# %%
df_hp = df[df['Company'] == 'HP']
df_hp
# Out:
#      Company                                  Product   TypeName  Inches  \
# 2         HP                                   250 G6   Notebook    15.6
# 10        HP                                   250 G6   Notebook    15.6
# 11        HP                                   250 G6   Notebook    15.6
# 22        HP                                   255 G6   Notebook    15.6
# 24        HP  15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)  Ultrabook    15.6
# ...      ...                                      ...        ...     ...
# 1282      HP                         Stream 11-Y000na    Netbook    11.6
# 1287      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook    15.6
# 1294      HP                      Pavilion 15-AW003nv   Notebook    15.6
# 1296      HP                         Stream 11-Y000na    Netbook    11.6
# 1301      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook    15.6
#
#        ScreenResolution                                   Cpu  Ram  \
# ...

# %%
df_hp['Price_euros'].max()
# Out:
# 4389.0

# %%
df_hp.sort_values('Price_euros')
# Out:
#      Company            Product            TypeName  Inches  \
# 1268      HP   Stream 11-Y000na             Netbook    11.6
# 1296      HP   Stream 11-Y000na             Netbook    11.6
# 1282      HP   Stream 11-Y000na             Netbook    11.6
# 67        HP  Stream 14-AX040wm            Notebook    14.0
# 1168      HP  Stream 14-AX000nv            Notebook    14.0
# ...      ...                ...                 ...     ...
# 857       HP     EliteBook x360  2 in 1 Convertible    13.3
# 1103      HP           ZBook 17         Workstation    17.3
# 911       HP    Elitebook Folio           Ultrabook    12.5
# 1136      HP           ZBook 17         Workstation    17.3
# 749       HP           Zbook 17         Workstation    17.3
#
#                          ScreenResolution  \
# 1268                             1366x768
# 1296                             1366x768
# 1282                             1366x768
# 67                               1366x768
# ...

# %%
df_ultra = df[df['TypeName'] == 'Ultrabook']
df_ultra
# Out:
#      Company               Product   TypeName  Inches  \
# 0      Apple           MacBook Pro  Ultrabook    13.3
# 1      Apple           Macbook Air  Ultrabook    13.3
# 3      Apple           MacBook Pro  Ultrabook    15.4
# 4      Apple           MacBook Pro  Ultrabook    13.3
# 6      Apple           MacBook Pro  Ultrabook    15.4
# ...      ...                   ...        ...     ...
# 1236      HP         EliteBook 840  Ultrabook    14.0
# 1241    Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1261    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1275    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1289    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                         ScreenResolution                         Cpu   Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                               1440x900        Intel Core i5 1.8GHz   8GB
# 3     IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# ...

# %%
df_ultra_8 = df_ultra[df_ultra['Ram'] == '8GB']
df_ultra_8
# Out:
#      Company               Product   TypeName  Inches  \
# 0      Apple           MacBook Pro  Ultrabook    13.3
# 1      Apple           Macbook Air  Ultrabook    13.3
# 4      Apple           MacBook Pro  Ultrabook    13.3
# 7      Apple           Macbook Air  Ultrabook    13.3
# 9       Acer               Swift 3  Ultrabook    14.0
# ...      ...                   ...        ...     ...
# 1236      HP         EliteBook 840  Ultrabook    14.0
# 1241    Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1261    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1275    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1289    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                               1440x900        Intel Core i5 1.8GHz  8GB
# 4     IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz  8GB
# ...

# %%
df_win = df[df['OpSys'] == 'Windows 10']
df_win
# Out:
#      Company                              Product            TypeName  Inches  \
# 5       Acer                             Aspire 3            Notebook    15.6
# 8       Asus                      ZenBook UX430UN           Ultrabook    14.0
# 9       Acer                              Swift 3           Ultrabook    14.0
# 13      Dell                        Inspiron 3567            Notebook    15.6
# 16      Dell                        Inspiron 3567            Notebook    15.6
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df_win_sorted=df_win.sort_values('Price_euros')
df_win_sorted.head(40)
# Out:
#        Company                               Product            TypeName  \
# 20        Asus                       Vivobook E200HA             Netbook
# 1120      Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)            Notebook
# 31        Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)            Notebook
# 791       Vero             K146 (N3350/4GB/32GB/W10)            Notebook
# 1296        HP                      Stream 11-Y000na             Netbook
# 1268        HP                      Stream 11-Y000na             Netbook
# 1282        HP                      Stream 11-Y000na             Netbook
# 1041      Vero          V142 (X5-Z8350/2GB/32GB/W10)            Notebook
# 1272    Lenovo                    IdeaPad 100S-14IBR            Notebook
# 67          HP                     Stream 14-AX040wm            Notebook
# 1300    Lenovo                    IdeaPad 100S-14IBR            Notebook
# 1286    Lenovo                    IdeaPad 100S-14IBR            Notebook
# ...

# %%
df_win_sorted.reindex()
# Out:
#      Company                               Product  TypeName  Inches  \
# 20      Asus                       Vivobook E200HA   Netbook    11.6
# 1120    Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)  Notebook    13.3
# 31      Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)  Notebook    14.0
# 791     Vero             K146 (N3350/4GB/32GB/W10)  Notebook    14.0
# 1296      HP                      Stream 11-Y000na   Netbook    11.6
# ...      ...                                   ...       ...     ...
# 238     Asus                     ROG G703VI-E5062T    Gaming    17.3
# 1066    Asus                            ROG G701VO    Gaming    17.3
# 610   Lenovo                          Thinkpad P51  Notebook    15.6
# 830    Razer                             Blade Pro    Gaming    17.3
# 196    Razer                             Blade Pro    Gaming    17.3
#
#                          ScreenResolution  \
# 20                               1366x768
# 1120                    Full HD 1920x1080
# ...

# %%
df_win_ram = df[(df['OpSys'] == 'Windows 10') & ((df['Ram'] == '16GB') | (df['Ram'] == '8GB')) & (df['Price_euros'] < 500.0)]
df_win_ram
# Out:
#      Company                                   Product  TypeName  Inches  \
# 74      Acer                             Aspire E5-475  Notebook    14.0
# 175     Dell                             Inspiron 3567  Notebook    15.6
# 256       HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook    15.6
# 292       HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook    17.3
# 313     Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook    15.6
# 365       HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook    15.6
# 571       HP            14-am079na (N3710/8GB/2TB/W10)  Notebook    14.0
# 595   Lenovo                         IdeaPad 110-15ISK  Notebook    15.6
# 634     Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook    15.6
# 702   Lenovo                         IdeaPad 320-15ABR  Notebook    15.6
# 1057    Acer                            Aspire ES1-523  Notebook    15.6
# 1163  Lenovo                         IdeaPad 310-15ISK  Notebook    15.6
# ...

# %%
df_win_ram['TypeName'].value_counts()
# Out:
# Notebook    13
# Name: TypeName, dtype: int64

# %%
df_win_ram.shape
# Out:
# (13, 12)

# %% [markdown]
# 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?

# %%
df_msi = df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & (df['Inches'] != 15.6)]
df_msi
# Out:
#      Company        Product TypeName  Inches   ScreenResolution  \
# 330      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393      MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 724      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917      MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1156     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# 393   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1349.00
# ...

# %%
df_msi.sort_values('Price_euros')
# Out:
#      Company        Product TypeName  Inches   ScreenResolution  \
# 330      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 724      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393      MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 1156     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917      MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# 724   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1348.48
# ...

# %% [markdown]
# 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
df_cpu = df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']
df_cpu
# Out:
#      Company                                    Product   TypeName  Inches  \
# 41      Dell                              Inspiron 7577     Gaming    15.6
# 58       MSI                                 GS73VR 7RG     Gaming    17.3
# 65      Asus                                ZenBook Pro  Ultrabook    15.6
# 69      Asus  FX753VE-GC093 (i7-7700HQ/12GB/1TB/GeForce     Gaming    17.3
# 75      Asus  FX503VD-E4022T (i7-7700HQ/8GB/1TB/GeForce     Gaming    15.6
# ...      ...                                        ...        ...     ...
# 1214    Asus                                  ROG Strix     Gaming    17.3
# 1229     MSI                                 GL62M 7RDX     Gaming    15.6
# 1231   Razer                                  Blade Pro     Gaming    14.0
# 1233     MSI                              GE72VR Apache     Gaming    17.3
# 1245    Asus                         Rog GL553VE-FY052T     Gaming    15.6
#
# ...

# %%
df_cpu2 = df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']
df_cpu2
# Out:
#        Company         Product            TypeName  Inches  \
# 306         HP  EliteBook x360  2 in 1 Convertible    13.3
# 407       Dell   Latitude 7480           Ultrabook    14.0
# 427       Dell   Latitude 5480           Ultrabook    14.0
# 433     Lenovo   Thinkpad T570         Workstation    15.6
# 497         HP   EliteBook 840            Notebook    14.0
# 535       Dell   Latitude 5580            Notebook    15.6
# 583       Dell   Latitude 5580            Notebook    15.6
# 670  Microsoft  Surface Laptop           Ultrabook    13.5
# 744     Lenovo   Thinkpad P51s         Workstation    15.6
# 761       Dell   Latitude 7280           Ultrabook    12.5
# 857         HP  EliteBook x360  2 in 1 Convertible    13.3
# 875       Dell   Latitude 7280           Ultrabook    12.5
# 951       Dell   Latitude 7480           Ultrabook    14.0
#
#                     ScreenResolution                         Cpu   Ram  \
# ...

# %%
df.head(1)
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight  Price_euros
# 0  1.37kg      1339.69

# %%
df_cpu.loc[10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
